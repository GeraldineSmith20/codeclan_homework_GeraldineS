# %% [markdown]
# Question 1:

# %%
import pandas as pd

# %%
drinks_content = pd.read_csv("data/starbucks_drinkMenu_expanded.csv")

# %%
drinks_content
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
drinks_content.shape
# Out:
# (242, 18)

# %%
drinks_content.columns
# Out:
# Index(['Beverage_category', 'Beverage', 'Beverage_prep', 'Calories',
#        ' Total Fat (g)', 'Trans Fat (g) ', 'Saturated Fat (g)', ' Sodium (mg)',
#        ' Total Carbohydrates (g) ', 'Cholesterol (mg)', ' Dietary Fibre (g)',
#        ' Sugars (g)', ' Protein (g) ', 'Vitamin A (% DV) ', 'Vitamin C (% DV)',
#        ' Calcium (% DV) ', 'Iron (% DV) ', 'Caffeine (mg)'],
#       dtype='object')

# %% [markdown]
# Question 2:

# %%
drinks_content['Calories'].describe()
# Out:
# count    242.000000
# mean     193.871901
# std      102.863303
# min        0.000000
# 25%      120.000000
# 50%      185.000000
# 75%      260.000000
# max      510.000000
# Name: Calories, dtype: float64

# %% [markdown]
# Question 3

# %%
drinks = drinks_content.loc[:, ['Beverage_category', 'Beverage', 'Beverage_prep', 'Calories']].copy()

# %%
drinks.isna().sum()
# Out:
# Beverage_category    0
# Beverage             0
# Beverage_prep        0
# Calories             0
# dtype: int64

# %% [markdown]
# Question 4

# %%
drinks['calorie_diff'] = 135 - drinks['Calories']

# %%
drinks
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %% [markdown]
# Question 5

# %%
drinks.groupby('Beverage_category')['Calories'].mean().reset_index(name = 'avg_calories').sort_values('avg_calories')
# Out:
#                    Beverage_category  avg_calories
# 1                             Coffee      4.250000
# 5              Shaken Iced Beverages    114.444444
# 0            Classic Espresso Drinks    140.172414
# 4  Frappuccino® Light Blended Coffee    162.500000
# 8                   Tazo® Tea Drinks    177.307692
# 3         Frappuccino® Blended Crème    233.076923
# 6          Signature Espresso Drinks    250.000000
# 2        Frappuccino® Blended Coffee    276.944444
# 7                          Smoothies    282.222222

# %% [markdown]
# Lowest calories - Coffee, Shaken Iced Beverages, Classic Espresso Drinks
# Highest calories - Smoothies, Frappuccino Blended Coffee, Signature Espresso Drinks

# %% [markdown]
# Question 6

# %%
drinks['Calories'].mean()
# Out:
# 193.87190082644628

# %%
bev_prep = drinks.groupby('Beverage_category')['Calories'].mean().reset_index(name = 'avg_calories').sort_values('avg_calories')

# %%
bev_prep
# Out:
#                    Beverage_category  avg_calories
# 1                             Coffee      4.250000
# 5              Shaken Iced Beverages    114.444444
# 0            Classic Espresso Drinks    140.172414
# 4  Frappuccino® Light Blended Coffee    162.500000
# 8                   Tazo® Tea Drinks    177.307692
# 3         Frappuccino® Blended Crème    233.076923
# 6          Signature Espresso Drinks    250.000000
# 2        Frappuccino® Blended Coffee    276.944444
# 7                          Smoothies    282.222222

# %%
bev_prep.loc[bev_prep['avg_calories'] > drinks['Calories'].mean()]
# Out:
#              Beverage_category  avg_calories
# 3   Frappuccino® Blended Crème    233.076923
# 6    Signature Espresso Drinks    250.000000
# 2  Frappuccino® Blended Coffee    276.944444
# 7                    Smoothies    282.222222

# %% [markdown]
# Question 7

# %%
drinks.loc[drinks['Beverage_category'] == 'Coffee'].sort_values('Calories')
# Out:
#   Beverage_category       Beverage Beverage_prep  Calories  calorie_diff
# 0            Coffee  Brewed Coffee         Short         3           132
# 1            Coffee  Brewed Coffee          Tall         4           131
# 2            Coffee  Brewed Coffee        Grande         5           130
# 3            Coffee  Brewed Coffee         Venti         5           130

# %% [markdown]
# Best drink is short brewed coffee?

# %% [markdown]
# Question 8

# %%
espresso_drinks = drinks.loc[drinks['Beverage_category'] == 'Classic Espresso Drinks'].copy()

# %% [markdown]
# Question 9 & 10

# %%
espresso_drinks.groupby('Beverage_prep')['Calories'].mean().reset_index(name = 'avg_calories').sort_values('avg_calories')
# Out:
#          Beverage_prep  avg_calories
# 4                Short         5.000
# 6                 Solo         5.000
# 1               Doppio        10.000
# 8                 Tall        10.000
# 2               Grande        15.000
# 10               Venti        25.000
# 5    Short Nonfat Milk        78.000
# 9     Tall Nonfat Milk       116.000
# 3   Grande Nonfat Milk       150.000
# 7              Soymilk       151.250
# 0              2% Milk       184.375
# 11   Venti Nonfat Milk       194.000
